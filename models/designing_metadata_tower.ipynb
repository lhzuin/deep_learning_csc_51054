# %%
import torch
import torch.nn as nn
class MetaTower(nn.Module):
    def __init__(self, in_dim, hidden_dim=32, out_dim=16):
        super().__init__()
        self.mlp = nn.Sequential(
            nn.Linear(in_dim, hidden_dim),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(hidden_dim, out_dim),
            nn.ReLU(),
        )
        self.classifier = nn.Linear(out_dim, 1)  # for metadata-only training

    def forward(self, x, return_logits=False):
        h = self.mlp(x)              # h_meta
        logits = self.classifier(h)  # metadata-only prediction
        if return_logits:
            return h, logits
        return h

# %%
import numpy as np
import pandas as pd
import re, ast, hashlib
from pathlib import Path

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, roc_auc_score

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

# ============================================================
# 1. Parsing + author_pseudo_id + basic metadata columns
# ============================================================

def parse_tweets_meta(path, expect_label=True):
    """
    Parse the raw train.jsonl and build a flat DataFrame with:
    - author_pseudo_id
    - basic tweet/user fields
    - simple structural flags (is_reply, has_media, etc.)
    """
    path = Path(path)
    df = pd.read_json(path, lines=True)
    df = pd.json_normalize(df.to_dict(orient="records"), sep=".")

    # Ensure some nested columns exist
    for col in [
        "text", "extended_tweet.full_text", "source",
        "entities.hashtags", "entities.user_mentions", "entities.urls",
        "extended_entities.media",
        "user.created_at", "user.description", "user.url", "user.location",
        "user.favourites_count", "user.statuses_count", "user.listed_count",
        "user.default_profile", "user.geo_enabled",
        "in_reply_to_status_id", "in_reply_to_user_id",
    ]:
        if col not in df.columns:
            df[col] = np.nan

    # -------- full text ----------
    df["full_text"] = df["extended_tweet.full_text"].fillna(df["text"]).fillna("")
    df["text_len"] = df["full_text"].str.len()

    # -------- counts / list lengths ----------
    def safe_len(x):
        if isinstance(x, list):
            return len(x)
        if isinstance(x, str):
            try:
                v = ast.literal_eval(x)
                return len(v) if isinstance(v, (list, tuple)) else 1
            except Exception:
                return 0
        return 0

    df["n_hashtags"] = df["entities.hashtags"].apply(safe_len)
    df["n_mentions"] = df["entities.user_mentions"].apply(safe_len)
    df["n_urls"]     = df["entities.urls"].apply(safe_len)

    # media flag
    df["has_media"] = df["extended_entities.media"].apply(lambda x: safe_len(x) > 0)

    # -------- author_pseudo_id ----------
    def make_user_key(row):
        key = (
            str(row.get("user.created_at", "")) + "|" +
            str(row.get("user.description", "")) + "|" +
            str(row.get("user.url", "")) + "|" +
            str(row.get("user.location", ""))
        )
        return hashlib.md5(key.encode("utf-8")).hexdigest()

    df["author_pseudo_id"] = df.apply(make_user_key, axis=1)

    # -------- structural flags ----------
    df["is_reply"] = (
        df["in_reply_to_status_id"].notna() |
        df["in_reply_to_user_id"].notna()
    )

    # approximate retweet flag (not used here, but harmless)
    df["is_retweet"] = df["text"].fillna("").str.startswith("RT @")

    # ensure boolean columns exist (even if missing)
    for col in ["user.default_profile", "user.geo_enabled"]:
        if col not in df.columns:
            df[col] = np.nan

    # -------- source_app (HTML → readable name) ----------
    def extract_source(x):
        if not isinstance(x, str):
            return "Unknown"
        m = re.search(r'>([^<]+)<', x)
        return m.group(1) if m else x

    df["source_app"] = df["source"].apply(extract_source)

    # keep only metadata we care about:
    keep_cols = [
        "author_pseudo_id", "full_text",
        "challenge_id" if "challenge_id" in df.columns else None,
        "n_hashtags", "n_mentions", "n_urls", "has_media",
        "user.favourites_count", "user.statuses_count", "user.listed_count",
        "user.default_profile", "user.geo_enabled",
        "is_reply", "text_len", "source_app",
    ]
    keep_cols = [c for c in keep_cols if c is not None]

    out = df[keep_cols].copy()

    # attach label if present
    if expect_label and "label" in df.columns:
        out["label"] = df["label"]
    elif expect_label and "label" not in df.columns:
        print("Warning: 'label' not found in this file; returning features only.")

    return out


# ============================================================
# 2. Feature engineering for metadata features
# ============================================================

def build_meta_features(df, fit_stats=None, src2idx=None, K=15):
    """
    Build metadata features:
      - log_status (from user.statuses_count)
      - log_listed (from user.listed_count)
      - log_fav   (from user.favourites_count)
      - n_mentions, n_hashtags
      - booleans as 0/1
      - source_idx: bucketized from source_app with top-K on TRAIN
    """
    df = df.copy()

    # ensure numeric columns exist
    for col in ["user.statuses_count", "user.listed_count", "user.favourites_count"]:
        if col not in df.columns:
            df[col] = 0

    # fit_stats = dict with p99s, learned from train set only
    if fit_stats is None:
        fit_stats = {}
        for col in ["user.statuses_count", "user.listed_count", "user.favourites_count"]:
            fit_stats[f"{col}_p99"] = float(df[col].quantile(0.995))

    # log transforms with clipping
    df["log_status"] = np.log1p(
        np.clip(df["user.statuses_count"].fillna(0), 0, fit_stats["user.statuses_count_p99"])
    )
    df["log_listed"] = np.log1p(
        np.clip(df["user.listed_count"].fillna(0), 0, fit_stats["user.listed_count_p99"])
    )
    df["log_fav"] = np.log1p(
        np.clip(df["user.favourites_count"].fillna(0), 0, fit_stats["user.favourites_count_p99"])
    )

    # counts
    df["n_mentions"] = df["n_mentions"].fillna(0).astype(int)
    df["n_hashtags"] = df["n_hashtags"].fillna(0).astype(int)

    # booleans → 0/1
    for bcol in ["has_media", "is_reply", "user.default_profile", "user.geo_enabled"]:
        if bcol not in df.columns:
            df[bcol] = False
        df[bcol] = df[bcol].fillna(False).astype(int)

    # ---- source_idx from source_app ----
    if "source_app" not in df.columns:
        df["source_app"] = "Unknown"

    if src2idx is None:
        top_src = df["source_app"].fillna("Unknown").value_counts().head(K).index.tolist()
        src2idx = {s: i + 1 for i, s in enumerate(top_src)}  # 0 reserved for "Other"

    df["source_idx"] = (
        df["source_app"]
        .fillna("Unknown")
        .map(src2idx)
        .fillna(0)
        .astype(int)
    )

    return df, fit_stats, src2idx


# ============================================================
# 3. Author-based split (no user overlap)
# ============================================================

def author_based_split(df, val_size=0.1, random_state=42):
    """
    Split df into train/val such that authors (author_pseudo_id)
    do not overlap between train and val.
    """
    assert "author_pseudo_id" in df.columns, "author_pseudo_id column missing"

    user_ids = df["author_pseudo_id"].astype(str)
    unique_users = user_ids.unique()

    train_users, val_users = train_test_split(
        unique_users, test_size=val_size, random_state=random_state
    )

    train_mask = user_ids.isin(train_users)
    val_mask   = user_ids.isin(val_users)

    train_df = df[train_mask].reset_index(drop=True)
    val_df   = df[val_mask].reset_index(drop=True)

    print("User-level split:")
    print("  #train tweets:", len(train_df))
    print("  #val tweets:  ", len(val_df))
    print("  #unique users train:", len(np.unique(user_ids[train_mask])))
    print("  #unique users val:  ", len(np.unique(user_ids[val_mask])))

    return train_df, val_df


# ============================================================
# 4. MetaTower (PyTorch MLP)
# ============================================================

class MetaTower(nn.Module):
    def __init__(self, in_dim, hidden_dim=32, out_dim=16, dropout=0.1):
        super().__init__()
        self.mlp = nn.Sequential(
            nn.Linear(in_dim, hidden_dim),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim, out_dim),
            nn.ReLU(),
        )
        self.classifier = nn.Linear(out_dim, 1)  # metadata-only training

    def forward(self, x, return_logits=False):
        h = self.mlp(x)              # h_meta
        logits = self.classifier(h)  # (B, 1)
        if return_logits:
            return h, logits
        return h


# ============================================================
# 5. Training loop for MetaTower on best_with_seven
# ============================================================

def train_meta_tower(
    train_df,
    val_df,
    feature_cols,
    batch_size=512,
    lr=1e-3,
    n_epochs=10,
    dropout=0.1,
    hidden_dim=32,
    device=None,
):
    if device is None:
        device = "cuda" if torch.cuda.is_available() else "cpu"
    print("Using device:", device)

    # --- prepare numpy arrays ---
    X_train = train_df[feature_cols].values.astype(np.float32)
    X_val   = val_df[feature_cols].values.astype(np.float32)

    y_train = train_df["label"].astype(np.float32).values
    y_val   = val_df["label"].astype(np.float32).values

    # --- standardize features (fit on train only) ---
    scaler = StandardScaler()
    X_train_sc = scaler.fit_transform(X_train)
    X_val_sc   = scaler.transform(X_val)

    # --- to tensors ---
    X_train_t = torch.from_numpy(X_train_sc)
    y_train_t = torch.from_numpy(y_train).unsqueeze(1)  # (N,1)
    X_val_t   = torch.from_numpy(X_val_sc)
    y_val_t   = torch.from_numpy(y_val).unsqueeze(1)

    train_ds = TensorDataset(X_train_t, y_train_t)
    val_ds   = TensorDataset(X_val_t, y_val_t)

    train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
    val_loader   = DataLoader(val_ds, batch_size=batch_size, shuffle=False)

    # --- model, loss, optimizer ---
    model = MetaTower(in_dim=len(feature_cols), hidden_dim=hidden_dim, out_dim=16, dropout=dropout).to(device)
    criterion = nn.BCEWithLogitsLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)

    # --- training loop ---
    for epoch in range(1, n_epochs + 1):
        model.train()
        train_losses = []

        for xb, yb in train_loader:
            xb = xb.to(device)
            yb = yb.to(device)

            _, logits = model(xb, return_logits=True)
            loss = criterion(logits, yb)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            train_losses.append(loss.item())

        # quick validation loss each epoch
        model.eval()
        val_losses = []
        with torch.no_grad():
            for xb, yb in val_loader:
                xb = xb.to(device)
                yb = yb.to(device)
                _, logits = model(xb, return_logits=True)
                loss = criterion(logits, yb)
                val_losses.append(loss.item())

        print(
            f"Epoch {epoch:02d} | "
            f"train_loss={np.mean(train_losses):.4f} | "
            f"val_loss={np.mean(val_losses):.4f}"
        )

    # --- final evaluation (accuracy + AUC on val) ---
    model.eval()
    with torch.no_grad():
        _, logits_val = model(X_val_t.to(device), return_logits=True)
        probs_val = torch.sigmoid(logits_val).cpu().numpy().ravel()
        preds_val = (probs_val >= 0.5).astype(int)
        y_true    = y_val.astype(int)

    acc = accuracy_score(y_true, preds_val)
    auc = roc_auc_score(y_true, probs_val)

    print("\n=== MetaTower (best_with_seven) performance on user-based val ===")
    print(f"Accuracy: {acc:.4f}")
    print(f"AUC:      {auc:.4f}")

    return model, scaler, {"accuracy": acc, "auc": auc}


# ============================================================
# 6. Main: load data, build features, split, train MetaTower
# ============================================================

# ---- adjust path to your train.jsonl ----
train_path = "../../train.jsonl"   # <-- change if needed

# 1) parse with author_pseudo_id + raw meta
raw_df = parse_tweets_meta(train_path, expect_label=True)

# 2) author-based split BEFORE computing stats (important!)
train_raw, val_raw = author_based_split(raw_df, val_size=0.1, random_state=42)

# 3) build metadata features, with p99 stats fitted on TRAIN only
train_meta, stats, src2idx = build_meta_features(train_raw, fit_stats=None, src2idx=None, K=15)
val_meta, _, _             = build_meta_features(val_raw, fit_stats=stats, src2idx=src2idx, K=15)

# 4) sanity check: label distribution
print("\nTrain label distribution:")
print(train_meta["label"].value_counts(normalize=True).rename("proportion"))
print("\nVal label distribution:")
print(val_meta["label"].value_counts(normalize=True).rename("proportion"))

# 5) define your best_with_seven feature set
best_with_seven = [
    "log_status",
    "log_listed",
    "user.default_profile",
    "is_reply",
    "n_mentions",
    "log_fav",
    "source_idx",
]

# 6) train MetaTower on these features with user-based validation
meta_model, meta_scaler, meta_metrics = train_meta_tower(
    train_meta,
    val_meta,
    feature_cols=best_with_seven,
    batch_size=128,
    lr=1e-3,
    n_epochs=10,
    dropout=0.1,
)
# Out:
# User-level split:
#   #train tweets: 139426
#   #val tweets:   15488
#   #unique users train: 44158
#   #unique users val:   4907
#
# Train label distribution:
# label
# 0    0.534556
# 1    0.465444
# Name: proportion, dtype: float64
#
# Val label distribution:
# label
# 0    0.525762
# 1    0.474238
# Name: proportion, dtype: float64
# Using device: cuda
# Epoch 01 | train_loss=0.4495 | val_loss=0.4175
# Epoch 02 | train_loss=0.4210 | val_loss=0.4148
# Epoch 03 | train_loss=0.4180 | val_loss=0.4129
# Epoch 04 | train_loss=0.4160 | val_loss=0.4117
# Epoch 05 | train_loss=0.4154 | val_loss=0.4120
# Epoch 06 | train_loss=0.4147 | val_loss=0.4114
# Epoch 07 | train_loss=0.4141 | val_loss=0.4119
# Epoch 08 | train_loss=0.4130 | val_loss=0.4099
# Epoch 09 | train_loss=0.4129 | val_loss=0.4098
# Epoch 10 | train_loss=0.4117 | val_loss=0.4115
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8208
# AUC:      0.8937

# %%
# Performing Grid Search -> hidden_dim=32

def grid_search_meta_tower(
    train_df,
    val_df,
    feature_cols,
    lr_list=(1e-2, 5e-3, 1e-3, 5e-4),
    n_epochs_list=(5, 10, 15),
    dropout_list=(0.0, 0.1, 0.2),
    batch_size=512,
    device=None,
):
    """
    Brute-force grid over (lr, n_epochs, dropout).
    Reuses train_meta_tower and returns the best config by AUC.
    """
    results = []
    best_auc = -np.inf
    best_result = None
    best_model = None
    best_scaler = None

    for lr in lr_list:
        for n_epochs in n_epochs_list:
            for dp in dropout_list:
                print("\n" + "=" * 60)
                print(f"Trying config: lr={lr}, n_epochs={n_epochs}, dropout={dp}")
                print("=" * 60)

                model, scaler, metrics = train_meta_tower(
                    train_df=train_df,
                    val_df=val_df,
                    feature_cols=feature_cols,
                    batch_size=batch_size,
                    lr=lr,
                    n_epochs=n_epochs,
                    dropout=dp,
                    device=device,
                )

                acc = metrics["accuracy"]
                auc = metrics["auc"]

                res = {
                    "lr": lr,
                    "n_epochs": n_epochs,
                    "dropout": dp,
                    "accuracy": acc,
                    "auc": auc,
                }
                results.append(res)

                if auc > best_auc:
                    best_auc = auc
                    best_result = res
                    best_model = model
                    best_scaler = scaler

    results_df = pd.DataFrame(results).sort_values(
        ["auc", "accuracy"], ascending=False
    ).reset_index(drop=True)

    print("\n=== Grid search summary (sorted by AUC, then accuracy) ===")
    print(results_df.head(10))
    print("\nBest config found:", best_result)

    return best_model, best_scaler, best_result, results_df


# ============================================================
# 6. Main: load data, build features, split, run grid search
# ============================================================

# ---- adjust path to your train.jsonl ----
train_path = "../../train.jsonl"   # <-- change if needed

# 1) parse with author_pseudo_id + raw meta
raw_df = parse_tweets_meta(train_path, expect_label=True)

# 2) author-based split BEFORE computing stats (important!)
train_raw, val_raw = author_based_split(raw_df, val_size=0.1, random_state=42)

# 3) build metadata features, with p99 stats fitted on TRAIN only
train_meta, stats, src2idx = build_meta_features(train_raw, fit_stats=None, src2idx=None, K=15)
val_meta, _, _             = build_meta_features(val_raw, fit_stats=stats, src2idx=src2idx, K=15)

# 4) sanity check: label distribution
print("\nTrain label distribution:")
print(train_meta["label"].value_counts(normalize=True).rename("proportion"))
print("\nVal label distribution:")
print(val_meta["label"].value_counts(normalize=True).rename("proportion"))

# 5) define your best_with_seven feature set
best_with_seven = [
    "log_status",
    "log_listed",
    "user.default_profile",
    "is_reply",
    "n_mentions",
    "log_fav",
    "source_idx",
]

# 6) run grid search instead of a single training run
best_model, best_scaler, best_result, grid_df = grid_search_meta_tower(
    train_meta,
    val_meta,
    feature_cols=best_with_seven,
    lr_list=(1e-2, 5e-3, 1e-3, 5e-4),
    n_epochs_list=(5, 10, 15),
    dropout_list=(0.0, 0.1, 0.2),
    batch_size=256,
)
# Out:
# User-level split:
#   #train tweets: 139426
#   #val tweets:   15488
#   #unique users train: 44158
#   #unique users val:   4907
#
# Train label distribution:
# label
# 0    0.534556
# 1    0.465444
# Name: proportion, dtype: float64
#
# Val label distribution:
# label
# 0    0.525762
# 1    0.474238
# Name: proportion, dtype: float64
#
# ============================================================
# Trying config: lr=0.01, n_epochs=5, dropout=0.0
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4218 | val_loss=0.4126
# Epoch 02 | train_loss=0.4116 | val_loss=0.4092
# Epoch 03 | train_loss=0.4090 | val_loss=0.4108
# Epoch 04 | train_loss=0.4062 | val_loss=0.4115
# Epoch 05 | train_loss=0.4054 | val_loss=0.4134
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8205
# AUC:      0.8940
#
# ============================================================
# Trying config: lr=0.01, n_epochs=5, dropout=0.1
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4266 | val_loss=0.4134
# Epoch 02 | train_loss=0.4167 | val_loss=0.4150
# Epoch 03 | train_loss=0.4150 | val_loss=0.4113
# Epoch 04 | train_loss=0.4125 | val_loss=0.4139
# Epoch 05 | train_loss=0.4121 | val_loss=0.4067
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8246
# AUC:      0.8959
#
# ============================================================
# Trying config: lr=0.01, n_epochs=5, dropout=0.2
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4319 | val_loss=0.4197
# Epoch 02 | train_loss=0.4195 | val_loss=0.4126
# Epoch 03 | train_loss=0.4168 | val_loss=0.4145
# Epoch 04 | train_loss=0.4150 | val_loss=0.4168
# Epoch 05 | train_loss=0.4147 | val_loss=0.4112
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8194
# AUC:      0.8946
#
# ============================================================
# Trying config: lr=0.01, n_epochs=10, dropout=0.0
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4218 | val_loss=0.4151
# Epoch 02 | train_loss=0.4111 | val_loss=0.4093
# Epoch 03 | train_loss=0.4087 | val_loss=0.4100
# Epoch 04 | train_loss=0.4075 | val_loss=0.4118
# Epoch 05 | train_loss=0.4051 | val_loss=0.4106
# Epoch 06 | train_loss=0.4041 | val_loss=0.4097
# Epoch 07 | train_loss=0.4032 | val_loss=0.4064
# Epoch 08 | train_loss=0.4022 | val_loss=0.4091
# Epoch 09 | train_loss=0.4015 | val_loss=0.4065
# Epoch 10 | train_loss=0.4011 | val_loss=0.4033
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8243
# AUC:      0.8971
#
# ============================================================
# Trying config: lr=0.01, n_epochs=10, dropout=0.1
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4256 | val_loss=0.4158
# Epoch 02 | train_loss=0.4160 | val_loss=0.4150
# Epoch 03 | train_loss=0.4130 | val_loss=0.4079
# Epoch 04 | train_loss=0.4116 | val_loss=0.4067
# Epoch 05 | train_loss=0.4095 | val_loss=0.4087
# Epoch 06 | train_loss=0.4085 | val_loss=0.4104
# Epoch 07 | train_loss=0.4082 | val_loss=0.4150
# Epoch 08 | train_loss=0.4079 | val_loss=0.4048
# Epoch 09 | train_loss=0.4073 | val_loss=0.4049
# Epoch 10 | train_loss=0.4066 | val_loss=0.4062
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8222
# AUC:      0.8966
#
# ============================================================
# Trying config: lr=0.01, n_epochs=10, dropout=0.2
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4300 | val_loss=0.4182
# Epoch 02 | train_loss=0.4182 | val_loss=0.4120
# Epoch 03 | train_loss=0.4167 | val_loss=0.4162
# Epoch 04 | train_loss=0.4156 | val_loss=0.4144
# Epoch 05 | train_loss=0.4151 | val_loss=0.4098
# Epoch 06 | train_loss=0.4137 | val_loss=0.4108
# Epoch 07 | train_loss=0.4126 | val_loss=0.4157
# Epoch 08 | train_loss=0.4122 | val_loss=0.4110
# Epoch 09 | train_loss=0.4117 | val_loss=0.4105
# Epoch 10 | train_loss=0.4110 | val_loss=0.4113
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8228
# AUC:      0.8950
#
# ============================================================
# Trying config: lr=0.01, n_epochs=15, dropout=0.0
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4221 | val_loss=0.4118
# Epoch 02 | train_loss=0.4114 | val_loss=0.4096
# Epoch 03 | train_loss=0.4081 | val_loss=0.4114
# Epoch 04 | train_loss=0.4057 | val_loss=0.4116
# Epoch 05 | train_loss=0.4045 | val_loss=0.4130
# Epoch 06 | train_loss=0.4031 | val_loss=0.4106
# Epoch 07 | train_loss=0.4021 | val_loss=0.4042
# Epoch 08 | train_loss=0.4016 | val_loss=0.4049
# Epoch 09 | train_loss=0.4017 | val_loss=0.4054
# Epoch 10 | train_loss=0.4007 | val_loss=0.4062
# Epoch 11 | train_loss=0.4001 | val_loss=0.4093
# Epoch 12 | train_loss=0.4006 | val_loss=0.4070
# Epoch 13 | train_loss=0.3992 | val_loss=0.4075
# Epoch 14 | train_loss=0.3997 | val_loss=0.4056
# Epoch 15 | train_loss=0.3991 | val_loss=0.4096
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8217
# AUC:      0.8952
#
# ============================================================
# Trying config: lr=0.01, n_epochs=15, dropout=0.1
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4266 | val_loss=0.4146
# Epoch 02 | train_loss=0.4158 | val_loss=0.4092
# Epoch 03 | train_loss=0.4130 | val_loss=0.4089
# Epoch 04 | train_loss=0.4116 | val_loss=0.4087
# Epoch 05 | train_loss=0.4103 | val_loss=0.4085
# Epoch 06 | train_loss=0.4084 | val_loss=0.4081
# Epoch 07 | train_loss=0.4076 | val_loss=0.4062
# Epoch 08 | train_loss=0.4062 | val_loss=0.4101
# Epoch 09 | train_loss=0.4061 | val_loss=0.4067
# Epoch 10 | train_loss=0.4055 | val_loss=0.4081
# Epoch 11 | train_loss=0.4049 | val_loss=0.4025
# Epoch 12 | train_loss=0.4048 | val_loss=0.4090
# Epoch 13 | train_loss=0.4044 | val_loss=0.4060
# Epoch 14 | train_loss=0.4043 | val_loss=0.4070
# Epoch 15 | train_loss=0.4042 | val_loss=0.4073
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8237
# AUC:      0.8953
#
# ============================================================
# Trying config: lr=0.01, n_epochs=15, dropout=0.2
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4315 | val_loss=0.4172
# Epoch 02 | train_loss=0.4183 | val_loss=0.4151
# Epoch 03 | train_loss=0.4171 | val_loss=0.4107
# Epoch 04 | train_loss=0.4153 | val_loss=0.4108
# Epoch 05 | train_loss=0.4143 | val_loss=0.4097
# Epoch 06 | train_loss=0.4133 | val_loss=0.4178
# Epoch 07 | train_loss=0.4121 | val_loss=0.4111
# Epoch 08 | train_loss=0.4115 | val_loss=0.4111
# Epoch 09 | train_loss=0.4106 | val_loss=0.4082
# Epoch 10 | train_loss=0.4104 | val_loss=0.4125
# Epoch 11 | train_loss=0.4101 | val_loss=0.4115
# Epoch 12 | train_loss=0.4098 | val_loss=0.4111
# Epoch 13 | train_loss=0.4100 | val_loss=0.4055
# Epoch 14 | train_loss=0.4096 | val_loss=0.4110
# Epoch 15 | train_loss=0.4091 | val_loss=0.4124
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8194
# AUC:      0.8950
#
# ============================================================
# Trying config: lr=0.005, n_epochs=5, dropout=0.0
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4289 | val_loss=0.4142
# Epoch 02 | train_loss=0.4119 | val_loss=0.4107
# Epoch 03 | train_loss=0.4096 | val_loss=0.4080
# Epoch 04 | train_loss=0.4072 | val_loss=0.4093
# Epoch 05 | train_loss=0.4047 | val_loss=0.4107
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8188
# AUC:      0.8954
#
# ============================================================
# Trying config: lr=0.005, n_epochs=5, dropout=0.1
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4321 | val_loss=0.4139
# Epoch 02 | train_loss=0.4159 | val_loss=0.4106
# Epoch 03 | train_loss=0.4141 | val_loss=0.4096
# Epoch 04 | train_loss=0.4121 | val_loss=0.4095
# Epoch 05 | train_loss=0.4113 | val_loss=0.4074
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8217
# AUC:      0.8950
#
# ============================================================
# Trying config: lr=0.005, n_epochs=5, dropout=0.2
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4327 | val_loss=0.4138
# Epoch 02 | train_loss=0.4183 | val_loss=0.4154
# Epoch 03 | train_loss=0.4163 | val_loss=0.4166
# Epoch 04 | train_loss=0.4146 | val_loss=0.4106
# Epoch 05 | train_loss=0.4129 | val_loss=0.4121
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8224
# AUC:      0.8931
#
# ============================================================
# Trying config: lr=0.005, n_epochs=10, dropout=0.0
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4244 | val_loss=0.4128
# Epoch 02 | train_loss=0.4111 | val_loss=0.4106
# Epoch 03 | train_loss=0.4083 | val_loss=0.4098
# Epoch 04 | train_loss=0.4063 | val_loss=0.4095
# Epoch 05 | train_loss=0.4050 | val_loss=0.4088
# Epoch 06 | train_loss=0.4037 | val_loss=0.4135
# Epoch 07 | train_loss=0.4031 | val_loss=0.4083
# Epoch 08 | train_loss=0.4019 | val_loss=0.4151
# Epoch 09 | train_loss=0.4016 | val_loss=0.4108
# Epoch 10 | train_loss=0.4010 | val_loss=0.4085
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8229
# AUC:      0.8939
#
# ============================================================
# Trying config: lr=0.005, n_epochs=10, dropout=0.1
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4318 | val_loss=0.4180
# Epoch 02 | train_loss=0.4161 | val_loss=0.4137
# Epoch 03 | train_loss=0.4147 | val_loss=0.4199
# Epoch 04 | train_loss=0.4120 | val_loss=0.4135
# Epoch 05 | train_loss=0.4106 | val_loss=0.4087
# Epoch 06 | train_loss=0.4096 | val_loss=0.4140
# Epoch 07 | train_loss=0.4087 | val_loss=0.4091
# Epoch 08 | train_loss=0.4085 | val_loss=0.4063
# Epoch 09 | train_loss=0.4085 | val_loss=0.4125
# Epoch 10 | train_loss=0.4078 | val_loss=0.4060
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8237
# AUC:      0.8955
#
# ============================================================
# Trying config: lr=0.005, n_epochs=10, dropout=0.2
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4370 | val_loss=0.4172
# Epoch 02 | train_loss=0.4193 | val_loss=0.4128
# Epoch 03 | train_loss=0.4171 | val_loss=0.4132
# Epoch 04 | train_loss=0.4160 | val_loss=0.4152
# Epoch 05 | train_loss=0.4143 | val_loss=0.4107
# Epoch 06 | train_loss=0.4138 | val_loss=0.4123
# Epoch 07 | train_loss=0.4135 | val_loss=0.4116
# Epoch 08 | train_loss=0.4127 | val_loss=0.4081
# Epoch 09 | train_loss=0.4117 | val_loss=0.4165
# Epoch 10 | train_loss=0.4120 | val_loss=0.4089
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8244
# AUC:      0.8945
#
# ============================================================
# Trying config: lr=0.005, n_epochs=15, dropout=0.0
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4256 | val_loss=0.4117
# Epoch 02 | train_loss=0.4110 | val_loss=0.4090
# Epoch 03 | train_loss=0.4087 | val_loss=0.4164
# Epoch 04 | train_loss=0.4075 | val_loss=0.4115
# Epoch 05 | train_loss=0.4056 | val_loss=0.4083
# Epoch 06 | train_loss=0.4050 | val_loss=0.4110
# Epoch 07 | train_loss=0.4038 | val_loss=0.4126
# Epoch 08 | train_loss=0.4029 | val_loss=0.4077
# Epoch 09 | train_loss=0.4025 | val_loss=0.4095
# Epoch 10 | train_loss=0.4020 | val_loss=0.4083
# Epoch 11 | train_loss=0.4014 | val_loss=0.4118
# Epoch 12 | train_loss=0.4013 | val_loss=0.4062
# Epoch 13 | train_loss=0.4004 | val_loss=0.4057
# Epoch 14 | train_loss=0.4003 | val_loss=0.4163
# Epoch 15 | train_loss=0.3998 | val_loss=0.4096
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8193
# AUC:      0.8955
#
# ============================================================
# Trying config: lr=0.005, n_epochs=15, dropout=0.1
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4323 | val_loss=0.4170
# Epoch 02 | train_loss=0.4152 | val_loss=0.4137
# Epoch 03 | train_loss=0.4137 | val_loss=0.4137
# Epoch 04 | train_loss=0.4129 | val_loss=0.4100
# Epoch 05 | train_loss=0.4123 | val_loss=0.4095
# Epoch 06 | train_loss=0.4113 | val_loss=0.4082
# Epoch 07 | train_loss=0.4108 | val_loss=0.4117
# Epoch 08 | train_loss=0.4095 | val_loss=0.4119
# Epoch 09 | train_loss=0.4092 | val_loss=0.4096
# Epoch 10 | train_loss=0.4084 | val_loss=0.4073
# Epoch 11 | train_loss=0.4088 | val_loss=0.4122
# Epoch 12 | train_loss=0.4081 | val_loss=0.4094
# Epoch 13 | train_loss=0.4078 | val_loss=0.4069
# Epoch 14 | train_loss=0.4073 | val_loss=0.4073
# Epoch 15 | train_loss=0.4065 | val_loss=0.4054
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8229
# AUC:      0.8959
#
# ============================================================
# Trying config: lr=0.005, n_epochs=15, dropout=0.2
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4357 | val_loss=0.4188
# Epoch 02 | train_loss=0.4184 | val_loss=0.4128
# Epoch 03 | train_loss=0.4167 | val_loss=0.4123
# Epoch 04 | train_loss=0.4154 | val_loss=0.4116
# Epoch 05 | train_loss=0.4139 | val_loss=0.4112
# Epoch 06 | train_loss=0.4140 | val_loss=0.4119
# Epoch 07 | train_loss=0.4133 | val_loss=0.4107
# Epoch 08 | train_loss=0.4122 | val_loss=0.4095
# Epoch 09 | train_loss=0.4116 | val_loss=0.4106
# Epoch 10 | train_loss=0.4112 | val_loss=0.4122
# Epoch 11 | train_loss=0.4100 | val_loss=0.4085
# Epoch 12 | train_loss=0.4099 | val_loss=0.4094
# Epoch 13 | train_loss=0.4090 | val_loss=0.4090
# Epoch 14 | train_loss=0.4086 | val_loss=0.4088
# Epoch 15 | train_loss=0.4086 | val_loss=0.4094
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8219
# AUC:      0.8963
#
# ============================================================
# Trying config: lr=0.001, n_epochs=5, dropout=0.0
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4572 | val_loss=0.4228
# Epoch 02 | train_loss=0.4163 | val_loss=0.4159
# Epoch 03 | train_loss=0.4129 | val_loss=0.4144
# Epoch 04 | train_loss=0.4110 | val_loss=0.4133
# Epoch 05 | train_loss=0.4098 | val_loss=0.4110
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8215
# AUC:      0.8933
#
# ============================================================
# Trying config: lr=0.001, n_epochs=5, dropout=0.1
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4607 | val_loss=0.4212
# Epoch 02 | train_loss=0.4212 | val_loss=0.4170
# Epoch 03 | train_loss=0.4177 | val_loss=0.4116
# Epoch 04 | train_loss=0.4157 | val_loss=0.4131
# Epoch 05 | train_loss=0.4146 | val_loss=0.4109
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8206
# AUC:      0.8937
#
# ============================================================
# Trying config: lr=0.001, n_epochs=5, dropout=0.2
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4711 | val_loss=0.4222
# Epoch 02 | train_loss=0.4270 | val_loss=0.4181
# Epoch 03 | train_loss=0.4218 | val_loss=0.4152
# Epoch 04 | train_loss=0.4197 | val_loss=0.4137
# Epoch 05 | train_loss=0.4188 | val_loss=0.4128
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8215
# AUC:      0.8928
#
# ============================================================
# Trying config: lr=0.001, n_epochs=10, dropout=0.0
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4557 | val_loss=0.4217
# Epoch 02 | train_loss=0.4160 | val_loss=0.4172
# Epoch 03 | train_loss=0.4128 | val_loss=0.4141
# Epoch 04 | train_loss=0.4114 | val_loss=0.4129
# Epoch 05 | train_loss=0.4103 | val_loss=0.4102
# Epoch 06 | train_loss=0.4094 | val_loss=0.4102
# Epoch 07 | train_loss=0.4085 | val_loss=0.4095
# Epoch 08 | train_loss=0.4077 | val_loss=0.4091
# Epoch 09 | train_loss=0.4069 | val_loss=0.4076
# Epoch 10 | train_loss=0.4064 | val_loss=0.4079
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8222
# AUC:      0.8951
#
# ============================================================
# Trying config: lr=0.001, n_epochs=10, dropout=0.1
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4639 | val_loss=0.4204
# Epoch 02 | train_loss=0.4217 | val_loss=0.4156
# Epoch 03 | train_loss=0.4175 | val_loss=0.4129
# Epoch 04 | train_loss=0.4157 | val_loss=0.4108
# Epoch 05 | train_loss=0.4141 | val_loss=0.4115
# Epoch 06 | train_loss=0.4125 | val_loss=0.4092
# Epoch 07 | train_loss=0.4127 | val_loss=0.4097
# Epoch 08 | train_loss=0.4121 | val_loss=0.4112
# Epoch 09 | train_loss=0.4113 | val_loss=0.4090
# Epoch 10 | train_loss=0.4113 | val_loss=0.4107
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8237
# AUC:      0.8942
#
# ============================================================
# Trying config: lr=0.001, n_epochs=10, dropout=0.2
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4729 | val_loss=0.4210
# Epoch 02 | train_loss=0.4265 | val_loss=0.4170
# Epoch 03 | train_loss=0.4209 | val_loss=0.4148
# Epoch 04 | train_loss=0.4197 | val_loss=0.4132
# Epoch 05 | train_loss=0.4188 | val_loss=0.4143
# Epoch 06 | train_loss=0.4182 | val_loss=0.4133
# Epoch 07 | train_loss=0.4170 | val_loss=0.4132
# Epoch 08 | train_loss=0.4165 | val_loss=0.4133
# Epoch 09 | train_loss=0.4158 | val_loss=0.4118
# Epoch 10 | train_loss=0.4154 | val_loss=0.4110
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8205
# AUC:      0.8932
#
# ============================================================
# Trying config: lr=0.001, n_epochs=15, dropout=0.0
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4550 | val_loss=0.4166
# Epoch 02 | train_loss=0.4132 | val_loss=0.4124
# Epoch 03 | train_loss=0.4112 | val_loss=0.4112
# Epoch 04 | train_loss=0.4100 | val_loss=0.4118
# Epoch 05 | train_loss=0.4091 | val_loss=0.4106
# Epoch 06 | train_loss=0.4084 | val_loss=0.4092
# Epoch 07 | train_loss=0.4077 | val_loss=0.4082
# Epoch 08 | train_loss=0.4072 | val_loss=0.4078
# Epoch 09 | train_loss=0.4069 | val_loss=0.4097
# Epoch 10 | train_loss=0.4065 | val_loss=0.4071
# Epoch 11 | train_loss=0.4061 | val_loss=0.4058
# Epoch 12 | train_loss=0.4057 | val_loss=0.4111
# Epoch 13 | train_loss=0.4052 | val_loss=0.4054
# Epoch 14 | train_loss=0.4051 | val_loss=0.4083
# Epoch 15 | train_loss=0.4047 | val_loss=0.4051
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8215
# AUC:      0.8960
#
# ============================================================
# Trying config: lr=0.001, n_epochs=15, dropout=0.1
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4665 | val_loss=0.4211
# Epoch 02 | train_loss=0.4221 | val_loss=0.4164
# Epoch 03 | train_loss=0.4175 | val_loss=0.4138
# Epoch 04 | train_loss=0.4152 | val_loss=0.4109
# Epoch 05 | train_loss=0.4145 | val_loss=0.4114
# Epoch 06 | train_loss=0.4134 | val_loss=0.4092
# Epoch 07 | train_loss=0.4125 | val_loss=0.4096
# Epoch 08 | train_loss=0.4127 | val_loss=0.4084
# Epoch 09 | train_loss=0.4117 | val_loss=0.4094
# Epoch 10 | train_loss=0.4112 | val_loss=0.4074
# Epoch 11 | train_loss=0.4108 | val_loss=0.4072
# Epoch 12 | train_loss=0.4101 | val_loss=0.4080
# Epoch 13 | train_loss=0.4102 | val_loss=0.4087
# Epoch 14 | train_loss=0.4097 | val_loss=0.4071
# Epoch 15 | train_loss=0.4092 | val_loss=0.4071
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8249
# AUC:      0.8954
#
# ============================================================
# Trying config: lr=0.001, n_epochs=15, dropout=0.2
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4667 | val_loss=0.4234
# Epoch 02 | train_loss=0.4265 | val_loss=0.4172
# Epoch 03 | train_loss=0.4228 | val_loss=0.4146
# Epoch 04 | train_loss=0.4202 | val_loss=0.4148
# Epoch 05 | train_loss=0.4194 | val_loss=0.4142
# Epoch 06 | train_loss=0.4180 | val_loss=0.4160
# Epoch 07 | train_loss=0.4166 | val_loss=0.4130
# Epoch 08 | train_loss=0.4160 | val_loss=0.4171
# Epoch 09 | train_loss=0.4158 | val_loss=0.4158
# Epoch 10 | train_loss=0.4150 | val_loss=0.4171
# Epoch 11 | train_loss=0.4154 | val_loss=0.4140
# Epoch 12 | train_loss=0.4145 | val_loss=0.4153
# Epoch 13 | train_loss=0.4136 | val_loss=0.4153
# Epoch 14 | train_loss=0.4133 | val_loss=0.4153
# Epoch 15 | train_loss=0.4131 | val_loss=0.4152
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8205
# AUC:      0.8935
#
# ============================================================
# Trying config: lr=0.0005, n_epochs=5, dropout=0.0
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4898 | val_loss=0.4273
# Epoch 02 | train_loss=0.4235 | val_loss=0.4194
# Epoch 03 | train_loss=0.4163 | val_loss=0.4170
# Epoch 04 | train_loss=0.4139 | val_loss=0.4160
# Epoch 05 | train_loss=0.4127 | val_loss=0.4154
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8199
# AUC:      0.8919
#
# ============================================================
# Trying config: lr=0.0005, n_epochs=5, dropout=0.1
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4909 | val_loss=0.4263
# Epoch 02 | train_loss=0.4273 | val_loss=0.4196
# Epoch 03 | train_loss=0.4220 | val_loss=0.4167
# Epoch 04 | train_loss=0.4198 | val_loss=0.4161
# Epoch 05 | train_loss=0.4184 | val_loss=0.4147
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8212
# AUC:      0.8918
#
# ============================================================
# Trying config: lr=0.0005, n_epochs=5, dropout=0.2
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.5098 | val_loss=0.4281
# Epoch 02 | train_loss=0.4324 | val_loss=0.4209
# Epoch 03 | train_loss=0.4270 | val_loss=0.4186
# Epoch 04 | train_loss=0.4244 | val_loss=0.4161
# Epoch 05 | train_loss=0.4225 | val_loss=0.4145
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8206
# AUC:      0.8914
#
# ============================================================
# Trying config: lr=0.0005, n_epochs=10, dropout=0.0
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4919 | val_loss=0.4278
# Epoch 02 | train_loss=0.4233 | val_loss=0.4193
# Epoch 03 | train_loss=0.4162 | val_loss=0.4167
# Epoch 04 | train_loss=0.4134 | val_loss=0.4149
# Epoch 05 | train_loss=0.4119 | val_loss=0.4134
# Epoch 06 | train_loss=0.4111 | val_loss=0.4132
# Epoch 07 | train_loss=0.4103 | val_loss=0.4126
# Epoch 08 | train_loss=0.4099 | val_loss=0.4109
# Epoch 09 | train_loss=0.4095 | val_loss=0.4110
# Epoch 10 | train_loss=0.4092 | val_loss=0.4110
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8217
# AUC:      0.8934
#
# ============================================================
# Trying config: lr=0.0005, n_epochs=10, dropout=0.1
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.5026 | val_loss=0.4265
# Epoch 02 | train_loss=0.4268 | val_loss=0.4191
# Epoch 03 | train_loss=0.4219 | val_loss=0.4159
# Epoch 04 | train_loss=0.4187 | val_loss=0.4164
# Epoch 05 | train_loss=0.4176 | val_loss=0.4147
# Epoch 06 | train_loss=0.4167 | val_loss=0.4135
# Epoch 07 | train_loss=0.4162 | val_loss=0.4129
# Epoch 08 | train_loss=0.4153 | val_loss=0.4120
# Epoch 09 | train_loss=0.4149 | val_loss=0.4135
# Epoch 10 | train_loss=0.4145 | val_loss=0.4112
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8216
# AUC:      0.8933
#
# ============================================================
# Trying config: lr=0.0005, n_epochs=10, dropout=0.2
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4999 | val_loss=0.4247
# Epoch 02 | train_loss=0.4316 | val_loss=0.4192
# Epoch 03 | train_loss=0.4252 | val_loss=0.4165
# Epoch 04 | train_loss=0.4222 | val_loss=0.4161
# Epoch 05 | train_loss=0.4204 | val_loss=0.4148
# Epoch 06 | train_loss=0.4194 | val_loss=0.4145
# Epoch 07 | train_loss=0.4188 | val_loss=0.4165
# Epoch 08 | train_loss=0.4176 | val_loss=0.4131
# Epoch 09 | train_loss=0.4174 | val_loss=0.4129
# Epoch 10 | train_loss=0.4173 | val_loss=0.4119
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8217
# AUC:      0.8928
#
# ============================================================
# Trying config: lr=0.0005, n_epochs=15, dropout=0.0
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4873 | val_loss=0.4259
# Epoch 02 | train_loss=0.4229 | val_loss=0.4215
# Epoch 03 | train_loss=0.4175 | val_loss=0.4168
# Epoch 04 | train_loss=0.4149 | val_loss=0.4159
# Epoch 05 | train_loss=0.4133 | val_loss=0.4155
# Epoch 06 | train_loss=0.4124 | val_loss=0.4139
# Epoch 07 | train_loss=0.4116 | val_loss=0.4132
# Epoch 08 | train_loss=0.4111 | val_loss=0.4132
# Epoch 09 | train_loss=0.4106 | val_loss=0.4128
# Epoch 10 | train_loss=0.4101 | val_loss=0.4122
# Epoch 11 | train_loss=0.4096 | val_loss=0.4106
# Epoch 12 | train_loss=0.4093 | val_loss=0.4100
# Epoch 13 | train_loss=0.4091 | val_loss=0.4096
# Epoch 14 | train_loss=0.4087 | val_loss=0.4103
# Epoch 15 | train_loss=0.4084 | val_loss=0.4116
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8212
# AUC:      0.8940
#
# ============================================================
# Trying config: lr=0.0005, n_epochs=15, dropout=0.1
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.5075 | val_loss=0.4283
# Epoch 02 | train_loss=0.4302 | val_loss=0.4215
# Epoch 03 | train_loss=0.4240 | val_loss=0.4187
# Epoch 04 | train_loss=0.4213 | val_loss=0.4165
# Epoch 05 | train_loss=0.4191 | val_loss=0.4156
# Epoch 06 | train_loss=0.4178 | val_loss=0.4131
# Epoch 07 | train_loss=0.4168 | val_loss=0.4140
# Epoch 08 | train_loss=0.4166 | val_loss=0.4127
# Epoch 09 | train_loss=0.4154 | val_loss=0.4116
# Epoch 10 | train_loss=0.4149 | val_loss=0.4122
# Epoch 11 | train_loss=0.4147 | val_loss=0.4127
# Epoch 12 | train_loss=0.4141 | val_loss=0.4114
# Epoch 13 | train_loss=0.4141 | val_loss=0.4116
# Epoch 14 | train_loss=0.4137 | val_loss=0.4110
# Epoch 15 | train_loss=0.4137 | val_loss=0.4101
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8231
# AUC:      0.8936
#
# ============================================================
# Trying config: lr=0.0005, n_epochs=15, dropout=0.2
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.5049 | val_loss=0.4277
# Epoch 02 | train_loss=0.4333 | val_loss=0.4220
# Epoch 03 | train_loss=0.4268 | val_loss=0.4191
# Epoch 04 | train_loss=0.4235 | val_loss=0.4158
# Epoch 05 | train_loss=0.4226 | val_loss=0.4162
# Epoch 06 | train_loss=0.4211 | val_loss=0.4168
# Epoch 07 | train_loss=0.4200 | val_loss=0.4141
# Epoch 08 | train_loss=0.4197 | val_loss=0.4147
# Epoch 09 | train_loss=0.4185 | val_loss=0.4141
# Epoch 10 | train_loss=0.4183 | val_loss=0.4141
# Epoch 11 | train_loss=0.4178 | val_loss=0.4158
# Epoch 12 | train_loss=0.4174 | val_loss=0.4130
# Epoch 13 | train_loss=0.4177 | val_loss=0.4141
# Epoch 14 | train_loss=0.4165 | val_loss=0.4128
# Epoch 15 | train_loss=0.4163 | val_loss=0.4130
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8212
# AUC:      0.8929
#
# === Grid search summary (sorted by AUC, then accuracy) ===
#       lr  n_epochs  dropout  accuracy       auc
# 0  0.010        10      0.0  0.824251  0.897052
# 1  0.010        10      0.1  0.822249  0.896618
# 2  0.005        15      0.2  0.821927  0.896259
# 3  0.001        15      0.0  0.821539  0.895987
# 4  0.005        15      0.1  0.822895  0.895876
# 5  0.010         5      0.1  0.824638  0.895876
# 6  0.005        10      0.1  0.823670  0.895514
# 7  0.005        15      0.0  0.819344  0.895458
# 8  0.001        15      0.1  0.824897  0.895445
# 9  0.005         5      0.0  0.818827  0.895400
#
# Best config found: {'lr': 0.01, 'n_epochs': 10, 'dropout': 0.0, 'accuracy': 0.8242510330578512, 'auc': 0.8970519392676868}

# %%
# Performing Grid Search

def grid_search_meta_tower(
    train_df,
    val_df,
    feature_cols,
    lr_list=(1e-2, 5e-3, 1e-3, 5e-4),
    n_epochs_list=(5, 10, 15),
    dropout_list=(0.0, 0.1, 0.2),
    hidden_dim_list=(16, 32, 64),
    batch_size=256,
    device=None,
):
    """
    Brute-force grid over (lr, n_epochs, dropout).
    Reuses train_meta_tower and returns the best config by AUC.
    """
    results = []
    best_auc = -np.inf
    best_result = None
    best_model = None
    best_scaler = None

    for lr in lr_list:
        for hidden_dim in hidden_dim_list:
            for n_epochs in n_epochs_list:
                for dp in dropout_list:
                    print("\n" + "=" * 60)
                    print(f"Trying config: lr={lr}, n_epochs={n_epochs}, dropout={dp}, hidden_dim={hidden_dim}")
                    print("=" * 60)

                    model, scaler, metrics = train_meta_tower(
                        train_df=train_df,
                        val_df=val_df,
                        feature_cols=feature_cols,
                        batch_size=batch_size,
                        lr=lr,
                        n_epochs=n_epochs,
                        dropout=dp,
                        hidden_dim=hidden_dim,
                        device=device,
                    )

                    acc = metrics["accuracy"]
                    auc = metrics["auc"]

                    res = {
                        "lr": lr,
                        "n_epochs": n_epochs,
                        "dropout": dp,
                        "hidden_dim": hidden_dim,
                        "accuracy": acc,
                        "auc": auc,
                    }
                    results.append(res)

                    if auc > best_auc:
                        best_auc = auc
                        best_result = res
                        best_model = model
                        best_scaler = scaler

    results_df = pd.DataFrame(results).sort_values(
        ["auc", "accuracy"], ascending=False
    ).reset_index(drop=True)

    print("\n=== Grid search summary (sorted by AUC, then accuracy) ===")
    print(results_df.head(10))
    print("\nBest config found:", best_result)

    return best_model, best_scaler, best_result, results_df


# ============================================================
# 6. Main: load data, build features, split, run grid search
# ============================================================

# ---- adjust path to your train.jsonl ----
train_path = "../../train.jsonl"   # <-- change if needed

# 1) parse with author_pseudo_id + raw meta
raw_df = parse_tweets_meta(train_path, expect_label=True)

# 2) author-based split BEFORE computing stats (important!)
train_raw, val_raw = author_based_split(raw_df, val_size=0.1, random_state=42)

# 3) build metadata features, with p99 stats fitted on TRAIN only
train_meta, stats, src2idx = build_meta_features(train_raw, fit_stats=None, src2idx=None, K=15)
val_meta, _, _             = build_meta_features(val_raw, fit_stats=stats, src2idx=src2idx, K=15)

# 4) sanity check: label distribution
print("\nTrain label distribution:")
print(train_meta["label"].value_counts(normalize=True).rename("proportion"))
print("\nVal label distribution:")
print(val_meta["label"].value_counts(normalize=True).rename("proportion"))

# 5) define your best_with_seven feature set
best_with_seven = [
    "log_status",
    "log_listed",
    "user.default_profile",
    "is_reply",
    "n_mentions",
    "log_fav",
    "source_idx",
]

# 6) run grid search instead of a single training run
best_model, best_scaler, best_result, grid_df = grid_search_meta_tower(
    train_meta,
    val_meta,
    feature_cols=best_with_seven,
    lr_list=(1e-2, 5e-3, 1e-3),
    n_epochs_list=(5, 10),
    dropout_list=(0.0, 0.1),
    hidden_dim_list=(16, 64),
    batch_size=256,
)
# Out:
# User-level split:
#   #train tweets: 139426
#   #val tweets:   15488
#   #unique users train: 44158
#   #unique users val:   4907
#
# Train label distribution:
# label
# 0    0.534556
# 1    0.465444
# Name: proportion, dtype: float64
#
# Val label distribution:
# label
# 0    0.525762
# 1    0.474238
# Name: proportion, dtype: float64
#
# ============================================================
# Trying config: lr=0.01, n_epochs=5, dropout=0.0
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4238 | val_loss=0.4170
# Epoch 02 | train_loss=0.4130 | val_loss=0.4151
# Epoch 03 | train_loss=0.4104 | val_loss=0.4162
# Epoch 04 | train_loss=0.4082 | val_loss=0.4117
# Epoch 05 | train_loss=0.4074 | val_loss=0.4080
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8211
# AUC:      0.8950
#
# ============================================================
# Trying config: lr=0.01, n_epochs=5, dropout=0.1
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4339 | val_loss=0.4165
# Epoch 02 | train_loss=0.4178 | val_loss=0.4173
# Epoch 03 | train_loss=0.4162 | val_loss=0.4164
# Epoch 04 | train_loss=0.4154 | val_loss=0.4142
# Epoch 05 | train_loss=0.4140 | val_loss=0.4177
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8157
# AUC:      0.8922
#
# ============================================================
# Trying config: lr=0.01, n_epochs=10, dropout=0.0
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4255 | val_loss=0.4165
# Epoch 02 | train_loss=0.4107 | val_loss=0.4118
# Epoch 03 | train_loss=0.4084 | val_loss=0.4156
# Epoch 04 | train_loss=0.4064 | val_loss=0.4165
# Epoch 05 | train_loss=0.4060 | val_loss=0.4135
# Epoch 06 | train_loss=0.4054 | val_loss=0.4099
# Epoch 07 | train_loss=0.4046 | val_loss=0.4123
# Epoch 08 | train_loss=0.4044 | val_loss=0.4077
# Epoch 09 | train_loss=0.4036 | val_loss=0.4073
# Epoch 10 | train_loss=0.4035 | val_loss=0.4076
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8197
# AUC:      0.8960
#
# ============================================================
# Trying config: lr=0.01, n_epochs=10, dropout=0.1
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4345 | val_loss=0.4151
# Epoch 02 | train_loss=0.4186 | val_loss=0.4142
# Epoch 03 | train_loss=0.4175 | val_loss=0.4152
# Epoch 04 | train_loss=0.4145 | val_loss=0.4115
# Epoch 05 | train_loss=0.4133 | val_loss=0.4098
# Epoch 06 | train_loss=0.4124 | val_loss=0.4108
# Epoch 07 | train_loss=0.4118 | val_loss=0.4111
# Epoch 08 | train_loss=0.4110 | val_loss=0.4092
# Epoch 09 | train_loss=0.4111 | val_loss=0.4077
# Epoch 10 | train_loss=0.4106 | val_loss=0.4110
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8207
# AUC:      0.8934
#
# ============================================================
# Trying config: lr=0.01, n_epochs=5, dropout=0.0
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4204 | val_loss=0.4115
# Epoch 02 | train_loss=0.4112 | val_loss=0.4132
# Epoch 03 | train_loss=0.4091 | val_loss=0.4067
# Epoch 04 | train_loss=0.4064 | val_loss=0.4174
# Epoch 05 | train_loss=0.4047 | val_loss=0.4064
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8229
# AUC:      0.8971
#
# ============================================================
# Trying config: lr=0.01, n_epochs=5, dropout=0.1
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4217 | val_loss=0.4188
# Epoch 02 | train_loss=0.4134 | val_loss=0.4096
# Epoch 03 | train_loss=0.4107 | val_loss=0.4113
# Epoch 04 | train_loss=0.4091 | val_loss=0.4067
# Epoch 05 | train_loss=0.4072 | val_loss=0.4061
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8251
# AUC:      0.8955
#
# ============================================================
# Trying config: lr=0.01, n_epochs=10, dropout=0.0
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4198 | val_loss=0.4130
# Epoch 02 | train_loss=0.4096 | val_loss=0.4088
# Epoch 03 | train_loss=0.4065 | val_loss=0.4051
# Epoch 04 | train_loss=0.4042 | val_loss=0.4089
# Epoch 05 | train_loss=0.4030 | val_loss=0.4068
# Epoch 06 | train_loss=0.4024 | val_loss=0.4083
# Epoch 07 | train_loss=0.4014 | val_loss=0.4144
# Epoch 08 | train_loss=0.4009 | val_loss=0.4068
# Epoch 09 | train_loss=0.3996 | val_loss=0.4055
# Epoch 10 | train_loss=0.3990 | val_loss=0.4106
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8216
# AUC:      0.8964
#
# ============================================================
# Trying config: lr=0.01, n_epochs=10, dropout=0.1
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4247 | val_loss=0.4195
# Epoch 02 | train_loss=0.4140 | val_loss=0.4152
# Epoch 03 | train_loss=0.4123 | val_loss=0.4082
# Epoch 04 | train_loss=0.4103 | val_loss=0.4278
# Epoch 05 | train_loss=0.4091 | val_loss=0.4197
# Epoch 06 | train_loss=0.4082 | val_loss=0.4092
# Epoch 07 | train_loss=0.4064 | val_loss=0.4068
# Epoch 08 | train_loss=0.4060 | val_loss=0.4064
# Epoch 09 | train_loss=0.4046 | val_loss=0.4067
# Epoch 10 | train_loss=0.4045 | val_loss=0.4063
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8206
# AUC:      0.8956
#
# ============================================================
# Trying config: lr=0.005, n_epochs=5, dropout=0.0
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4299 | val_loss=0.4140
# Epoch 02 | train_loss=0.4117 | val_loss=0.4143
# Epoch 03 | train_loss=0.4109 | val_loss=0.4148
# Epoch 04 | train_loss=0.4099 | val_loss=0.4158
# Epoch 05 | train_loss=0.4092 | val_loss=0.4102
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8195
# AUC:      0.8934
#
# ============================================================
# Trying config: lr=0.005, n_epochs=5, dropout=0.1
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4370 | val_loss=0.4144
# Epoch 02 | train_loss=0.4189 | val_loss=0.4141
# Epoch 03 | train_loss=0.4167 | val_loss=0.4118
# Epoch 04 | train_loss=0.4153 | val_loss=0.4182
# Epoch 05 | train_loss=0.4151 | val_loss=0.4177
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8184
# AUC:      0.8928
#
# ============================================================
# Trying config: lr=0.005, n_epochs=10, dropout=0.0
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4318 | val_loss=0.4147
# Epoch 02 | train_loss=0.4124 | val_loss=0.4128
# Epoch 03 | train_loss=0.4106 | val_loss=0.4097
# Epoch 04 | train_loss=0.4088 | val_loss=0.4131
# Epoch 05 | train_loss=0.4082 | val_loss=0.4104
# Epoch 06 | train_loss=0.4079 | val_loss=0.4087
# Epoch 07 | train_loss=0.4069 | val_loss=0.4072
# Epoch 08 | train_loss=0.4057 | val_loss=0.4077
# Epoch 09 | train_loss=0.4051 | val_loss=0.4110
# Epoch 10 | train_loss=0.4044 | val_loss=0.4075
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8217
# AUC:      0.8953
#
# ============================================================
# Trying config: lr=0.005, n_epochs=10, dropout=0.1
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4400 | val_loss=0.4156
# Epoch 02 | train_loss=0.4190 | val_loss=0.4128
# Epoch 03 | train_loss=0.4173 | val_loss=0.4105
# Epoch 04 | train_loss=0.4164 | val_loss=0.4127
# Epoch 05 | train_loss=0.4155 | val_loss=0.4101
# Epoch 06 | train_loss=0.4140 | val_loss=0.4091
# Epoch 07 | train_loss=0.4136 | val_loss=0.4089
# Epoch 08 | train_loss=0.4129 | val_loss=0.4122
# Epoch 09 | train_loss=0.4124 | val_loss=0.4094
# Epoch 10 | train_loss=0.4124 | val_loss=0.4073
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8234
# AUC:      0.8950
#
# ============================================================
# Trying config: lr=0.005, n_epochs=5, dropout=0.0
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4221 | val_loss=0.4154
# Epoch 02 | train_loss=0.4109 | val_loss=0.4120
# Epoch 03 | train_loss=0.4083 | val_loss=0.4118
# Epoch 04 | train_loss=0.4061 | val_loss=0.4087
# Epoch 05 | train_loss=0.4042 | val_loss=0.4060
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8231
# AUC:      0.8967
#
# ============================================================
# Trying config: lr=0.005, n_epochs=5, dropout=0.1
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4270 | val_loss=0.4132
# Epoch 02 | train_loss=0.4131 | val_loss=0.4135
# Epoch 03 | train_loss=0.4111 | val_loss=0.4094
# Epoch 04 | train_loss=0.4097 | val_loss=0.4071
# Epoch 05 | train_loss=0.4086 | val_loss=0.4076
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8210
# AUC:      0.8949
#
# ============================================================
# Trying config: lr=0.005, n_epochs=10, dropout=0.0
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4245 | val_loss=0.4164
# Epoch 02 | train_loss=0.4107 | val_loss=0.4097
# Epoch 03 | train_loss=0.4083 | val_loss=0.4079
# Epoch 04 | train_loss=0.4060 | val_loss=0.4069
# Epoch 05 | train_loss=0.4042 | val_loss=0.4071
# Epoch 06 | train_loss=0.4030 | val_loss=0.4055
# Epoch 07 | train_loss=0.4026 | val_loss=0.4043
# Epoch 08 | train_loss=0.4015 | val_loss=0.4068
# Epoch 09 | train_loss=0.4007 | val_loss=0.4106
# Epoch 10 | train_loss=0.3998 | val_loss=0.4082
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8218
# AUC:      0.8955
#
# ============================================================
# Trying config: lr=0.005, n_epochs=10, dropout=0.1
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4267 | val_loss=0.4140
# Epoch 02 | train_loss=0.4140 | val_loss=0.4112
# Epoch 03 | train_loss=0.4116 | val_loss=0.4106
# Epoch 04 | train_loss=0.4104 | val_loss=0.4115
# Epoch 05 | train_loss=0.4084 | val_loss=0.4088
# Epoch 06 | train_loss=0.4075 | val_loss=0.4088
# Epoch 07 | train_loss=0.4057 | val_loss=0.4058
# Epoch 08 | train_loss=0.4052 | val_loss=0.4046
# Epoch 09 | train_loss=0.4040 | val_loss=0.4041
# Epoch 10 | train_loss=0.4029 | val_loss=0.4056
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8249
# AUC:      0.8959
#
# ============================================================
# Trying config: lr=0.001, n_epochs=5, dropout=0.0
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4759 | val_loss=0.4239
# Epoch 02 | train_loss=0.4181 | val_loss=0.4175
# Epoch 03 | train_loss=0.4144 | val_loss=0.4152
# Epoch 04 | train_loss=0.4128 | val_loss=0.4150
# Epoch 05 | train_loss=0.4118 | val_loss=0.4125
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8201
# AUC:      0.8928
#
# ============================================================
# Trying config: lr=0.001, n_epochs=5, dropout=0.1
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4851 | val_loss=0.4263
# Epoch 02 | train_loss=0.4284 | val_loss=0.4195
# Epoch 03 | train_loss=0.4230 | val_loss=0.4153
# Epoch 04 | train_loss=0.4201 | val_loss=0.4147
# Epoch 05 | train_loss=0.4185 | val_loss=0.4149
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8194
# AUC:      0.8924
#
# ============================================================
# Trying config: lr=0.001, n_epochs=10, dropout=0.0
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4692 | val_loss=0.4265
# Epoch 02 | train_loss=0.4209 | val_loss=0.4194
# Epoch 03 | train_loss=0.4155 | val_loss=0.4158
# Epoch 04 | train_loss=0.4133 | val_loss=0.4141
# Epoch 05 | train_loss=0.4122 | val_loss=0.4128
# Epoch 06 | train_loss=0.4113 | val_loss=0.4125
# Epoch 07 | train_loss=0.4106 | val_loss=0.4148
# Epoch 08 | train_loss=0.4102 | val_loss=0.4125
# Epoch 09 | train_loss=0.4098 | val_loss=0.4123
# Epoch 10 | train_loss=0.4093 | val_loss=0.4106
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8211
# AUC:      0.8931
#
# ============================================================
# Trying config: lr=0.001, n_epochs=10, dropout=0.1
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4776 | val_loss=0.4275
# Epoch 02 | train_loss=0.4306 | val_loss=0.4196
# Epoch 03 | train_loss=0.4232 | val_loss=0.4159
# Epoch 04 | train_loss=0.4204 | val_loss=0.4138
# Epoch 05 | train_loss=0.4196 | val_loss=0.4129
# Epoch 06 | train_loss=0.4180 | val_loss=0.4141
# Epoch 07 | train_loss=0.4173 | val_loss=0.4125
# Epoch 08 | train_loss=0.4168 | val_loss=0.4118
# Epoch 09 | train_loss=0.4160 | val_loss=0.4161
# Epoch 10 | train_loss=0.4154 | val_loss=0.4127
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8219
# AUC:      0.8934
#
# ============================================================
# Trying config: lr=0.001, n_epochs=5, dropout=0.0
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4480 | val_loss=0.4200
# Epoch 02 | train_loss=0.4135 | val_loss=0.4140
# Epoch 03 | train_loss=0.4110 | val_loss=0.4139
# Epoch 04 | train_loss=0.4099 | val_loss=0.4111
# Epoch 05 | train_loss=0.4088 | val_loss=0.4118
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8213
# AUC:      0.8930
#
# ============================================================
# Trying config: lr=0.001, n_epochs=5, dropout=0.1
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4506 | val_loss=0.4196
# Epoch 02 | train_loss=0.4178 | val_loss=0.4160
# Epoch 03 | train_loss=0.4149 | val_loss=0.4130
# Epoch 04 | train_loss=0.4137 | val_loss=0.4128
# Epoch 05 | train_loss=0.4127 | val_loss=0.4143
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8202
# AUC:      0.8934
#
# ============================================================
# Trying config: lr=0.001, n_epochs=10, dropout=0.0
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4457 | val_loss=0.4190
# Epoch 02 | train_loss=0.4139 | val_loss=0.4139
# Epoch 03 | train_loss=0.4118 | val_loss=0.4116
# Epoch 04 | train_loss=0.4103 | val_loss=0.4095
# Epoch 05 | train_loss=0.4091 | val_loss=0.4110
# Epoch 06 | train_loss=0.4082 | val_loss=0.4094
# Epoch 07 | train_loss=0.4073 | val_loss=0.4098
# Epoch 08 | train_loss=0.4064 | val_loss=0.4083
# Epoch 09 | train_loss=0.4058 | val_loss=0.4073
# Epoch 10 | train_loss=0.4052 | val_loss=0.4074
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8226
# AUC:      0.8954
#
# ============================================================
# Trying config: lr=0.001, n_epochs=10, dropout=0.1
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4470 | val_loss=0.4194
# Epoch 02 | train_loss=0.4182 | val_loss=0.4126
# Epoch 03 | train_loss=0.4155 | val_loss=0.4148
# Epoch 04 | train_loss=0.4139 | val_loss=0.4114
# Epoch 05 | train_loss=0.4133 | val_loss=0.4114
# Epoch 06 | train_loss=0.4124 | val_loss=0.4095
# Epoch 07 | train_loss=0.4123 | val_loss=0.4119
# Epoch 08 | train_loss=0.4115 | val_loss=0.4087
# Epoch 09 | train_loss=0.4106 | val_loss=0.4094
# Epoch 10 | train_loss=0.4099 | val_loss=0.4080
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8224
# AUC:      0.8946
#
# === Grid search summary (sorted by AUC, then accuracy) ===
#       lr  n_epochs  dropout  hidden_dim  accuracy       auc
# 0  0.010         5      0.0          64  0.822895  0.897126
# 1  0.005         5      0.0          64  0.823089  0.896671
# 2  0.010        10      0.0          64  0.821604  0.896375
# 3  0.010        10      0.0          16  0.819731  0.896038
# 4  0.005        10      0.1          64  0.824897  0.895891
# 5  0.010        10      0.1          64  0.820571  0.895582
# 6  0.010         5      0.1          64  0.825090  0.895502
# 7  0.005        10      0.0          64  0.821798  0.895495
# 8  0.001        10      0.0          64  0.822572  0.895357
# 9  0.005        10      0.0          16  0.821733  0.895350
#
# Best config found: {'lr': 0.01, 'n_epochs': 5, 'dropout': 0.0, 'hidden_dim': 64, 'accuracy': 0.8228951446280992, 'auc': 0.8971263244053055}

# %%
# Performing Grid Search

def grid_search_meta_tower(
    train_df,
    val_df,
    feature_cols,
    lr_list=(1e-2, 5e-3, 1e-3, 5e-4),
    n_epochs_list=(5, 10, 15),
    dropout_list=(0.0, 0.1, 0.2),
    hidden_dim_list=(16, 32, 64),
    batch_size=256,
    device=None,
):
    """
    Brute-force grid over (lr, n_epochs, dropout).
    Reuses train_meta_tower and returns the best config by AUC.
    """
    results = []
    best_auc = -np.inf
    best_result = None
    best_model = None
    best_scaler = None

    for lr in lr_list:
        for hidden_dim in hidden_dim_list:
            for n_epochs in n_epochs_list:
                for dp in dropout_list:
                    print("\n" + "=" * 60)
                    print(f"Trying config: lr={lr}, n_epochs={n_epochs}, dropout={dp}, hidden_dim={hidden_dim}")
                    print("=" * 60)

                    model, scaler, metrics = train_meta_tower(
                        train_df=train_df,
                        val_df=val_df,
                        feature_cols=feature_cols,
                        batch_size=batch_size,
                        lr=lr,
                        n_epochs=n_epochs,
                        dropout=dp,
                        hidden_dim=hidden_dim,
                        device=device,
                    )

                    acc = metrics["accuracy"]
                    auc = metrics["auc"]

                    res = {
                        "lr": lr,
                        "n_epochs": n_epochs,
                        "dropout": dp,
                        "hidden_dim": hidden_dim,
                        "accuracy": acc,
                        "auc": auc,
                    }
                    results.append(res)

                    if auc > best_auc:
                        best_auc = auc
                        best_result = res
                        best_model = model
                        best_scaler = scaler

    results_df = pd.DataFrame(results).sort_values(
        ["auc", "accuracy"], ascending=False
    ).reset_index(drop=True)

    print("\n=== Grid search summary (sorted by AUC, then accuracy) ===")
    print(results_df.head(10))
    print("\nBest config found:", best_result)

    return best_model, best_scaler, best_result, results_df


# ============================================================
# 6. Main: load data, build features, split, run grid search
# ============================================================

# ---- adjust path to your train.jsonl ----
train_path = "../../train.jsonl"   # <-- change if needed

# 1) parse with author_pseudo_id + raw meta
raw_df = parse_tweets_meta(train_path, expect_label=True)

# 2) author-based split BEFORE computing stats (important!)
train_raw, val_raw = author_based_split(raw_df, val_size=0.1, random_state=42)

# 3) build metadata features, with p99 stats fitted on TRAIN only
train_meta, stats, src2idx = build_meta_features(train_raw, fit_stats=None, src2idx=None, K=15)
val_meta, _, _             = build_meta_features(val_raw, fit_stats=stats, src2idx=src2idx, K=15)

# 4) sanity check: label distribution
print("\nTrain label distribution:")
print(train_meta["label"].value_counts(normalize=True).rename("proportion"))
print("\nVal label distribution:")
print(val_meta["label"].value_counts(normalize=True).rename("proportion"))

# 5) define your best_with_seven feature set
best_with_seven = [
    "log_status",
    "log_listed",
    "user.default_profile",
    "is_reply",
    "n_mentions",
    "log_fav",
    "source_idx",
]

# 6) run grid search instead of a single training run
best_model, best_scaler, best_result, grid_df = grid_search_meta_tower(
    train_meta,
    val_meta,
    feature_cols=best_with_seven,
    lr_list=(1e-2, 5e-3),
    n_epochs_list=(5, 10, 15),
    dropout_list=(0.0, 0.1),
    hidden_dim_list=(32, 64),
    batch_size=256,
)
# Out:
# User-level split:
#   #train tweets: 139426
#   #val tweets:   15488
#   #unique users train: 44158
#   #unique users val:   4907
#
# Train label distribution:
# label
# 0    0.534556
# 1    0.465444
# Name: proportion, dtype: float64
#
# Val label distribution:
# label
# 0    0.525762
# 1    0.474238
# Name: proportion, dtype: float64
#
# ============================================================
# Trying config: lr=0.01, n_epochs=5, dropout=0.0, hidden_dim=32
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4236 | val_loss=0.4163
# Epoch 02 | train_loss=0.4128 | val_loss=0.4183
# Epoch 03 | train_loss=0.4093 | val_loss=0.4097
# Epoch 04 | train_loss=0.4063 | val_loss=0.4073
# Epoch 05 | train_loss=0.4045 | val_loss=0.4125
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8235
# AUC:      0.8964
#
# ============================================================
# Trying config: lr=0.01, n_epochs=5, dropout=0.1, hidden_dim=32
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4263 | val_loss=0.4191
# Epoch 02 | train_loss=0.4154 | val_loss=0.4129
# Epoch 03 | train_loss=0.4141 | val_loss=0.4138
# Epoch 04 | train_loss=0.4134 | val_loss=0.4113
# Epoch 05 | train_loss=0.4121 | val_loss=0.4096
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8241
# AUC:      0.8941
#
# ============================================================
# Trying config: lr=0.01, n_epochs=10, dropout=0.0, hidden_dim=32
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4230 | val_loss=0.4141
# Epoch 02 | train_loss=0.4108 | val_loss=0.4100
# Epoch 03 | train_loss=0.4089 | val_loss=0.4106
# Epoch 04 | train_loss=0.4063 | val_loss=0.4072
# Epoch 05 | train_loss=0.4045 | val_loss=0.4064
# Epoch 06 | train_loss=0.4036 | val_loss=0.4140
# Epoch 07 | train_loss=0.4026 | val_loss=0.4105
# Epoch 08 | train_loss=0.4019 | val_loss=0.4060
# Epoch 09 | train_loss=0.4012 | val_loss=0.4060
# Epoch 10 | train_loss=0.4009 | val_loss=0.4039
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8237
# AUC:      0.8966
#
# ============================================================
# Trying config: lr=0.01, n_epochs=10, dropout=0.1, hidden_dim=32
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4263 | val_loss=0.4150
# Epoch 02 | train_loss=0.4158 | val_loss=0.4126
# Epoch 03 | train_loss=0.4131 | val_loss=0.4153
# Epoch 04 | train_loss=0.4124 | val_loss=0.4140
# Epoch 05 | train_loss=0.4110 | val_loss=0.4122
# Epoch 06 | train_loss=0.4096 | val_loss=0.4143
# Epoch 07 | train_loss=0.4086 | val_loss=0.4214
# Epoch 08 | train_loss=0.4086 | val_loss=0.4097
# Epoch 09 | train_loss=0.4092 | val_loss=0.4121
# Epoch 10 | train_loss=0.4075 | val_loss=0.4108
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8221
# AUC:      0.8941
#
# ============================================================
# Trying config: lr=0.01, n_epochs=15, dropout=0.0, hidden_dim=32
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4237 | val_loss=0.4238
# Epoch 02 | train_loss=0.4111 | val_loss=0.4122
# Epoch 03 | train_loss=0.4090 | val_loss=0.4084
# Epoch 04 | train_loss=0.4055 | val_loss=0.4087
# Epoch 05 | train_loss=0.4040 | val_loss=0.4113
# Epoch 06 | train_loss=0.4032 | val_loss=0.4056
# Epoch 07 | train_loss=0.4023 | val_loss=0.4043
# Epoch 08 | train_loss=0.4016 | val_loss=0.4052
# Epoch 09 | train_loss=0.4011 | val_loss=0.4054
# Epoch 10 | train_loss=0.4007 | val_loss=0.4058
# Epoch 11 | train_loss=0.4005 | val_loss=0.4051
# Epoch 12 | train_loss=0.4001 | val_loss=0.4098
# Epoch 13 | train_loss=0.4001 | val_loss=0.4065
# Epoch 14 | train_loss=0.3997 | val_loss=0.4063
# Epoch 15 | train_loss=0.3993 | val_loss=0.4091
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8204
# AUC:      0.8948
#
# ============================================================
# Trying config: lr=0.01, n_epochs=15, dropout=0.1, hidden_dim=32
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4264 | val_loss=0.4144
# Epoch 02 | train_loss=0.4155 | val_loss=0.4128
# Epoch 03 | train_loss=0.4131 | val_loss=0.4104
# Epoch 04 | train_loss=0.4124 | val_loss=0.4121
# Epoch 05 | train_loss=0.4113 | val_loss=0.4091
# Epoch 06 | train_loss=0.4095 | val_loss=0.4111
# Epoch 07 | train_loss=0.4089 | val_loss=0.4082
# Epoch 08 | train_loss=0.4081 | val_loss=0.4064
# Epoch 09 | train_loss=0.4073 | val_loss=0.4148
# Epoch 10 | train_loss=0.4064 | val_loss=0.4128
# Epoch 11 | train_loss=0.4064 | val_loss=0.4064
# Epoch 12 | train_loss=0.4063 | val_loss=0.4118
# Epoch 13 | train_loss=0.4060 | val_loss=0.4072
# Epoch 14 | train_loss=0.4056 | val_loss=0.4064
# Epoch 15 | train_loss=0.4053 | val_loss=0.4088
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8235
# AUC:      0.8955
#
# ============================================================
# Trying config: lr=0.01, n_epochs=5, dropout=0.0, hidden_dim=64
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4198 | val_loss=0.4098
# Epoch 02 | train_loss=0.4092 | val_loss=0.4100
# Epoch 03 | train_loss=0.4063 | val_loss=0.4041
# Epoch 04 | train_loss=0.4043 | val_loss=0.4074
# Epoch 05 | train_loss=0.4028 | val_loss=0.4055
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8194
# AUC:      0.8958
#
# ============================================================
# Trying config: lr=0.01, n_epochs=5, dropout=0.1, hidden_dim=64
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4236 | val_loss=0.4138
# Epoch 02 | train_loss=0.4131 | val_loss=0.4099
# Epoch 03 | train_loss=0.4103 | val_loss=0.4143
# Epoch 04 | train_loss=0.4090 | val_loss=0.4089
# Epoch 05 | train_loss=0.4073 | val_loss=0.4080
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8234
# AUC:      0.8952
#
# ============================================================
# Trying config: lr=0.01, n_epochs=10, dropout=0.0, hidden_dim=64
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4204 | val_loss=0.4121
# Epoch 02 | train_loss=0.4108 | val_loss=0.4086
# Epoch 03 | train_loss=0.4081 | val_loss=0.4098
# Epoch 04 | train_loss=0.4052 | val_loss=0.4078
# Epoch 05 | train_loss=0.4039 | val_loss=0.4077
# Epoch 06 | train_loss=0.4029 | val_loss=0.4063
# Epoch 07 | train_loss=0.4018 | val_loss=0.4033
# Epoch 08 | train_loss=0.4012 | val_loss=0.4041
# Epoch 09 | train_loss=0.3998 | val_loss=0.4052
# Epoch 10 | train_loss=0.3991 | val_loss=0.4035
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8233
# AUC:      0.8969
#
# ============================================================
# Trying config: lr=0.01, n_epochs=10, dropout=0.1, hidden_dim=64
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4230 | val_loss=0.4119
# Epoch 02 | train_loss=0.4132 | val_loss=0.4100
# Epoch 03 | train_loss=0.4121 | val_loss=0.4077
# Epoch 04 | train_loss=0.4095 | val_loss=0.4124
# Epoch 05 | train_loss=0.4080 | val_loss=0.4111
# Epoch 06 | train_loss=0.4071 | val_loss=0.4105
# Epoch 07 | train_loss=0.4062 | val_loss=0.4097
# Epoch 08 | train_loss=0.4051 | val_loss=0.4058
# Epoch 09 | train_loss=0.4052 | val_loss=0.4080
# Epoch 10 | train_loss=0.4050 | val_loss=0.4115
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8225
# AUC:      0.8950
#
# ============================================================
# Trying config: lr=0.01, n_epochs=15, dropout=0.0, hidden_dim=64
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4199 | val_loss=0.4226
# Epoch 02 | train_loss=0.4107 | val_loss=0.4079
# Epoch 03 | train_loss=0.4077 | val_loss=0.4099
# Epoch 04 | train_loss=0.4044 | val_loss=0.4073
# Epoch 05 | train_loss=0.4028 | val_loss=0.4051
# Epoch 06 | train_loss=0.4021 | val_loss=0.4064
# Epoch 07 | train_loss=0.4010 | val_loss=0.4049
# Epoch 08 | train_loss=0.4000 | val_loss=0.4062
# Epoch 09 | train_loss=0.3993 | val_loss=0.4109
# Epoch 10 | train_loss=0.3989 | val_loss=0.4068
# Epoch 11 | train_loss=0.3983 | val_loss=0.4050
# Epoch 12 | train_loss=0.3981 | val_loss=0.4022
# Epoch 13 | train_loss=0.3970 | val_loss=0.4108
# Epoch 14 | train_loss=0.3967 | val_loss=0.4053
# Epoch 15 | train_loss=0.3967 | val_loss=0.4046
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8241
# AUC:      0.8972
#
# ============================================================
# Trying config: lr=0.01, n_epochs=15, dropout=0.1, hidden_dim=64
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4240 | val_loss=0.4128
# Epoch 02 | train_loss=0.4148 | val_loss=0.4142
# Epoch 03 | train_loss=0.4127 | val_loss=0.4131
# Epoch 04 | train_loss=0.4108 | val_loss=0.4089
# Epoch 05 | train_loss=0.4086 | val_loss=0.4077
# Epoch 06 | train_loss=0.4068 | val_loss=0.4092
# Epoch 07 | train_loss=0.4063 | val_loss=0.4065
# Epoch 08 | train_loss=0.4045 | val_loss=0.4082
# Epoch 09 | train_loss=0.4038 | val_loss=0.4062
# Epoch 10 | train_loss=0.4039 | val_loss=0.4128
# Epoch 11 | train_loss=0.4032 | val_loss=0.4071
# Epoch 12 | train_loss=0.4033 | val_loss=0.4051
# Epoch 13 | train_loss=0.4029 | val_loss=0.4096
# Epoch 14 | train_loss=0.4025 | val_loss=0.4074
# Epoch 15 | train_loss=0.4022 | val_loss=0.4070
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8248
# AUC:      0.8970
#
# ============================================================
# Trying config: lr=0.005, n_epochs=5, dropout=0.0, hidden_dim=32
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4283 | val_loss=0.4162
# Epoch 02 | train_loss=0.4122 | val_loss=0.4114
# Epoch 03 | train_loss=0.4101 | val_loss=0.4108
# Epoch 04 | train_loss=0.4082 | val_loss=0.4090
# Epoch 05 | train_loss=0.4072 | val_loss=0.4087
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8226
# AUC:      0.8948
#
# ============================================================
# Trying config: lr=0.005, n_epochs=5, dropout=0.1, hidden_dim=32
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4306 | val_loss=0.4155
# Epoch 02 | train_loss=0.4163 | val_loss=0.4130
# Epoch 03 | train_loss=0.4143 | val_loss=0.4096
# Epoch 04 | train_loss=0.4126 | val_loss=0.4102
# Epoch 05 | train_loss=0.4120 | val_loss=0.4163
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8198
# AUC:      0.8930
#
# ============================================================
# Trying config: lr=0.005, n_epochs=10, dropout=0.0, hidden_dim=32
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4256 | val_loss=0.4125
# Epoch 02 | train_loss=0.4103 | val_loss=0.4120
# Epoch 03 | train_loss=0.4077 | val_loss=0.4096
# Epoch 04 | train_loss=0.4065 | val_loss=0.4064
# Epoch 05 | train_loss=0.4051 | val_loss=0.4154
# Epoch 06 | train_loss=0.4045 | val_loss=0.4087
# Epoch 07 | train_loss=0.4033 | val_loss=0.4066
# Epoch 08 | train_loss=0.4023 | val_loss=0.4050
# Epoch 09 | train_loss=0.4020 | val_loss=0.4053
# Epoch 10 | train_loss=0.4015 | val_loss=0.4005
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8243
# AUC:      0.8985
#
# ============================================================
# Trying config: lr=0.005, n_epochs=10, dropout=0.1, hidden_dim=32
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4342 | val_loss=0.4147
# Epoch 02 | train_loss=0.4161 | val_loss=0.4166
# Epoch 03 | train_loss=0.4138 | val_loss=0.4095
# Epoch 04 | train_loss=0.4122 | val_loss=0.4121
# Epoch 05 | train_loss=0.4111 | val_loss=0.4079
# Epoch 06 | train_loss=0.4103 | val_loss=0.4071
# Epoch 07 | train_loss=0.4100 | val_loss=0.4102
# Epoch 08 | train_loss=0.4095 | val_loss=0.4058
# Epoch 09 | train_loss=0.4088 | val_loss=0.4078
# Epoch 10 | train_loss=0.4086 | val_loss=0.4064
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8244
# AUC:      0.8957
#
# ============================================================
# Trying config: lr=0.005, n_epochs=15, dropout=0.0, hidden_dim=32
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4268 | val_loss=0.4157
# Epoch 02 | train_loss=0.4119 | val_loss=0.4207
# Epoch 03 | train_loss=0.4090 | val_loss=0.4100
# Epoch 04 | train_loss=0.4073 | val_loss=0.4101
# Epoch 05 | train_loss=0.4055 | val_loss=0.4069
# Epoch 06 | train_loss=0.4048 | val_loss=0.4039
# Epoch 07 | train_loss=0.4034 | val_loss=0.4081
# Epoch 08 | train_loss=0.4026 | val_loss=0.4052
# Epoch 09 | train_loss=0.4020 | val_loss=0.4085
# Epoch 10 | train_loss=0.4013 | val_loss=0.4067
# Epoch 11 | train_loss=0.4010 | val_loss=0.4059
# Epoch 12 | train_loss=0.4005 | val_loss=0.4090
# Epoch 13 | train_loss=0.4001 | val_loss=0.4058
# Epoch 14 | train_loss=0.3997 | val_loss=0.4055
# Epoch 15 | train_loss=0.3994 | val_loss=0.4080
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8213
# AUC:      0.8949
#
# ============================================================
# Trying config: lr=0.005, n_epochs=15, dropout=0.1, hidden_dim=32
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4350 | val_loss=0.4170
# Epoch 02 | train_loss=0.4170 | val_loss=0.4108
# Epoch 03 | train_loss=0.4141 | val_loss=0.4098
# Epoch 04 | train_loss=0.4131 | val_loss=0.4109
# Epoch 05 | train_loss=0.4118 | val_loss=0.4102
# Epoch 06 | train_loss=0.4114 | val_loss=0.4086
# Epoch 07 | train_loss=0.4107 | val_loss=0.4110
# Epoch 08 | train_loss=0.4102 | val_loss=0.4085
# Epoch 09 | train_loss=0.4100 | val_loss=0.4065
# Epoch 10 | train_loss=0.4088 | val_loss=0.4081
# Epoch 11 | train_loss=0.4083 | val_loss=0.4063
# Epoch 12 | train_loss=0.4083 | val_loss=0.4078
# Epoch 13 | train_loss=0.4077 | val_loss=0.4096
# Epoch 14 | train_loss=0.4069 | val_loss=0.4087
# Epoch 15 | train_loss=0.4068 | val_loss=0.4071
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8226
# AUC:      0.8952
#
# ============================================================
# Trying config: lr=0.005, n_epochs=5, dropout=0.0, hidden_dim=64
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4220 | val_loss=0.4303
# Epoch 02 | train_loss=0.4112 | val_loss=0.4142
# Epoch 03 | train_loss=0.4087 | val_loss=0.4101
# Epoch 04 | train_loss=0.4066 | val_loss=0.4070
# Epoch 05 | train_loss=0.4045 | val_loss=0.4048
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8220
# AUC:      0.8961
#
# ============================================================
# Trying config: lr=0.005, n_epochs=5, dropout=0.1, hidden_dim=64
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4270 | val_loss=0.4128
# Epoch 02 | train_loss=0.4133 | val_loss=0.4111
# Epoch 03 | train_loss=0.4113 | val_loss=0.4126
# Epoch 04 | train_loss=0.4093 | val_loss=0.4139
# Epoch 05 | train_loss=0.4081 | val_loss=0.4067
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8230
# AUC:      0.8953
#
# ============================================================
# Trying config: lr=0.005, n_epochs=10, dropout=0.0, hidden_dim=64
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4231 | val_loss=0.4137
# Epoch 02 | train_loss=0.4107 | val_loss=0.4157
# Epoch 03 | train_loss=0.4076 | val_loss=0.4079
# Epoch 04 | train_loss=0.4051 | val_loss=0.4053
# Epoch 05 | train_loss=0.4035 | val_loss=0.4057
# Epoch 06 | train_loss=0.4022 | val_loss=0.4152
# Epoch 07 | train_loss=0.4014 | val_loss=0.4144
# Epoch 08 | train_loss=0.4007 | val_loss=0.4089
# Epoch 09 | train_loss=0.3998 | val_loss=0.4042
# Epoch 10 | train_loss=0.3989 | val_loss=0.4033
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8248
# AUC:      0.8972
#
# ============================================================
# Trying config: lr=0.005, n_epochs=10, dropout=0.1, hidden_dim=64
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4257 | val_loss=0.4170
# Epoch 02 | train_loss=0.4140 | val_loss=0.4122
# Epoch 03 | train_loss=0.4114 | val_loss=0.4128
# Epoch 04 | train_loss=0.4094 | val_loss=0.4075
# Epoch 05 | train_loss=0.4079 | val_loss=0.4073
# Epoch 06 | train_loss=0.4068 | val_loss=0.4057
# Epoch 07 | train_loss=0.4060 | val_loss=0.4068
# Epoch 08 | train_loss=0.4053 | val_loss=0.4057
# Epoch 09 | train_loss=0.4045 | val_loss=0.4058
# Epoch 10 | train_loss=0.4036 | val_loss=0.4033
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8261
# AUC:      0.8977
#
# ============================================================
# Trying config: lr=0.005, n_epochs=15, dropout=0.0, hidden_dim=64
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4227 | val_loss=0.4145
# Epoch 02 | train_loss=0.4105 | val_loss=0.4129
# Epoch 03 | train_loss=0.4082 | val_loss=0.4096
# Epoch 04 | train_loss=0.4055 | val_loss=0.4087
# Epoch 05 | train_loss=0.4043 | val_loss=0.4058
# Epoch 06 | train_loss=0.4028 | val_loss=0.4060
# Epoch 07 | train_loss=0.4023 | val_loss=0.4077
# Epoch 08 | train_loss=0.4016 | val_loss=0.4036
# Epoch 09 | train_loss=0.4009 | val_loss=0.4048
# Epoch 10 | train_loss=0.4005 | val_loss=0.4058
# Epoch 11 | train_loss=0.3998 | val_loss=0.4074
# Epoch 12 | train_loss=0.3999 | val_loss=0.4075
# Epoch 13 | train_loss=0.3992 | val_loss=0.4039
# Epoch 14 | train_loss=0.3992 | val_loss=0.4049
# Epoch 15 | train_loss=0.3987 | val_loss=0.4056
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8239
# AUC:      0.8971
#
# ============================================================
# Trying config: lr=0.005, n_epochs=15, dropout=0.1, hidden_dim=64
# ============================================================
# Using device: cuda
# Epoch 01 | train_loss=0.4264 | val_loss=0.4149
# Epoch 02 | train_loss=0.4140 | val_loss=0.4103
# Epoch 03 | train_loss=0.4117 | val_loss=0.4143
# Epoch 04 | train_loss=0.4101 | val_loss=0.4098
# Epoch 05 | train_loss=0.4090 | val_loss=0.4134
# Epoch 06 | train_loss=0.4078 | val_loss=0.4086
# Epoch 07 | train_loss=0.4069 | val_loss=0.4065
# Epoch 08 | train_loss=0.4053 | val_loss=0.4061
# Epoch 09 | train_loss=0.4052 | val_loss=0.4076
# Epoch 10 | train_loss=0.4040 | val_loss=0.4049
# Epoch 11 | train_loss=0.4037 | val_loss=0.4055
# Epoch 12 | train_loss=0.4034 | val_loss=0.4072
# Epoch 13 | train_loss=0.4025 | val_loss=0.4072
# Epoch 14 | train_loss=0.4030 | val_loss=0.4081
# Epoch 15 | train_loss=0.4028 | val_loss=0.4059
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8231
# AUC:      0.8968
#
# === Grid search summary (sorted by AUC, then accuracy) ===
#       lr  n_epochs  dropout  hidden_dim  accuracy       auc
# 0  0.005        10      0.0          32  0.824251  0.898510
# 1  0.005        10      0.1          64  0.826123  0.897691
# 2  0.010        15      0.0          64  0.824057  0.897212
# 3  0.005        10      0.0          64  0.824832  0.897187
# 4  0.005        15      0.0          64  0.823928  0.897051
# 5  0.010        15      0.1          64  0.824768  0.896976
# 6  0.010        10      0.0          64  0.823283  0.896903
# 7  0.005        15      0.1          64  0.823089  0.896787
# 8  0.010        10      0.0          32  0.823670  0.896583
# 9  0.010         5      0.0          32  0.823541  0.896409
#
# Best config found: {'lr': 0.005, 'n_epochs': 10, 'dropout': 0.0, 'hidden_dim': 32, 'accuracy': 0.8242510330578512, 'auc': 0.8985102992651689}

# %%
meta_model, meta_scaler, meta_metrics = train_meta_tower(
    train_meta,
    val_meta,
    feature_cols=best_with_seven,
    batch_size=128,
    lr=5e-3,
    n_epochs=10,
    hidden_dim=32,
    dropout=0.0,
)
print(meta_metrics)
# Out:
# Using device: cuda
# Epoch 01 | train_loss=0.4228 | val_loss=0.4159
# Epoch 02 | train_loss=0.4112 | val_loss=0.4129
# Epoch 03 | train_loss=0.4088 | val_loss=0.4111
# Epoch 04 | train_loss=0.4067 | val_loss=0.4059
# Epoch 05 | train_loss=0.4044 | val_loss=0.4029
# Epoch 06 | train_loss=0.4026 | val_loss=0.4060
# Epoch 07 | train_loss=0.4017 | val_loss=0.4038
# Epoch 08 | train_loss=0.4012 | val_loss=0.4029
# Epoch 09 | train_loss=0.4003 | val_loss=0.4043
# Epoch 10 | train_loss=0.3996 | val_loss=0.4042
#
# === MetaTower (best_with_seven) performance on user-based val ===
# Accuracy: 0.8244
# AUC:      0.8965
# {'accuracy': 0.8244447314049587, 'auc': 0.8965374796847402}

# %%
def save_meta_checkpoint(
    path,
    model,
    scaler,
    feature_cols,
    stats,
    src2idx,
    config,
    metrics,
):
    """
    Save everything needed to reuse the metadata tower later.
    """
    checkpoint = {
        "model_state_dict": model.state_dict(),
        "scaler": scaler,
        "feature_cols": feature_cols,
        "stats": stats,
        "src2idx": src2idx,
        "config": config,
        "metrics": metrics,
    }
    torch.save(checkpoint, path)
    print(f"Saved metadata tower checkpoint to: {path}")


best_config = {
    "hidden_dim": 32,
    "out_dim": 16,
    "lr": 3e-5,
    "n_epochs": 10,
    "dropout": 0.0,
}

save_meta_checkpoint(
    path="meta_tower_best.pt",
    model=best_model,
    scaler=best_scaler,
    feature_cols=best_with_seven,
    stats=stats,
    src2idx=src2idx,
    config=best_config,
    metrics=meta_metrics,
)
# Out:
# Saved metadata tower checkpoint to: meta_tower_best.pt

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
ckpt = torch.load("meta_tower_best.pt", map_location=device)

feature_cols = ckpt["feature_cols"]
stats        = ckpt["stats"]
src2idx      = ckpt["src2idx"]
config       = ckpt["config"]
scaler       = ckpt["scaler"]

model = MetaTower(
    in_dim=len(feature_cols),
    hidden_dim=config["hidden_dim"],
    out_dim=config["out_dim"],
    dropout=config["dropout"],
).to(device)

model.load_state_dict(ckpt["model_state_dict"])
model.eval()
